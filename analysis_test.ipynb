# %%
import time
import requests

# %%
DATA = "https://data-api.polymarket.com"
HEADERS = {"User-Agent": "pm-analysis/1.0"}

# %%
data = requests.get("https://data-api.polymarket.com/trades?user=0x81889df9f101a3b241186206eb26ccdfdb45d69bd3e025460321756b44547226&limit=2")
data._content
# Out:
# b'[{"proxyWallet":"0xd2b2cd8044cc7a19e12db9b09f4f12a1c3d0d101","side":"BUY","asset":"15570258397550727735064026820128250447700889085006392145796221495960859781407","conditionId":"0x56348e19c5c507f80cd46336db6278b85dc75d6511f10ca2d8a85abe356a5b3b","size":1492.537312,"price":0.6699999999732,"timestamp":1762703071,"title":"Falcons vs. Colts","slug":"nfl-atl-ind-2025-11-09","icon":"https://polymarket-upload.s3.us-east-2.amazonaws.com/nfl.png","eventSlug":"nfl-atl-ind-2025-11-09","outcome":"Colts","outcomeIndex":1,"name":"Adaniel1290","pseudonym":"Frail-Nationality","bio":"","profileImage":"","profileImageOptimized":"","transactionHash":"0x46ba0255fa580aafea7de0693c3cab06b968c2bfa09567e6acc1d5a784520ede"},{"proxyWallet":"0x101f6f00577b69ce5c0d0f7dcf0a3b1c4836eadb","side":"SELL","asset":"84566561349071752664514432513198569980219178901068420341175150225620958953893","conditionId":"0xfee07be730188c94cd3644ed6f107fa3ea2dfab9989ce8d39aeeae064766abe3","size":200.29,"price":0.992,"timestamp":176
# ...

# %%
print(dir(data))
# Out:
# ['__attrs__', '__bool__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_content', '_content_consumed', '_next', 'apparent_encoding', 'close', 'connection', 'content', 'cookies', 'elapsed', 'encoding', 'headers', 'history', 'is_permanent_redirect', 'is_redirect', 'iter_content', 'iter_lines', 'json', 'links', 'next', 'ok', 'raise_for_status', 'raw', 'reason', 'request', 'status_code', 'text', 'url']

# %%
import requests

url = "https://data-api.polymarket.com/trades"
params = {
    "user": "0x81889df9f101a3b241186206eb26ccdfdb45d69bd3e025460321756b44547226",
    "limit": 100,
    "takerOnly": "true"
}

r = requests.get(url, params=params)
print("Final URL:", r.url)   # requests shows what URL it actually built
print(r.json())
# Out:
# Final URL: https://data-api.polymarket.com/trades?user=0x81889df9f101a3b241186206eb26ccdfdb45d69bd3e025460321756b44547226&limit=2&takerOnly=true
# ...

# %%
r.json()[0]
# Out:
# {'proxyWallet': '0x3a5b912ae4e814f50eb3f83727ae37e1091c672b',
#  'side': 'BUY',
#  'asset': '46471982698413736935779229347673174367406840134478262515032551588448358664216',
#  'conditionId': '0x094ff55de25466e34e058dac1867b5d41c3f2a9d96cb37fd5943b1396fbcf95c',
#  'size': 1.807227,
#  'price': 0.9959999490932794,
#  'timestamp': 1762703095,
#  'title': 'Ethereum Up or Down on November 9?',
#  'slug': 'ethereum-up-or-down-on-november-9',
#  'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/ETH+fullsize.jpg',
#  'eventSlug': 'ethereum-up-or-down-on-november-9',
#  'outcome': 'Up',
#  'outcomeIndex': 0,
#  'name': '549a',
#  'pseudonym': 'Finished-Arrangement',
#  'bio': '',
#  'profileImage': '',
#  'profileImageOptimized': '',
#  'transactionHash': '0x1a62ad974f6b115aa4e936c21378ecb7e562021ef52f05e3691a99ce718c6555'}

# %%
r.json()[0]["price"]
# Out:
# 0.047

# %%
import requests
import pandas as pd

wallet = "0x22633134dc34f6c9a3bff51a0926c9d209714e26"
url = f"https://data-api.polymarket.com/user_positions?user={wallet}"

data = requests.get(url).json()
df = pd.DataFrame(data)

df
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File e:\work-test\polymarket_analysis\poly_env\Lib\site-packages\requests\models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\anaconda3\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...

# %%
url
# Out:
# 'https://data-api.polymarket.com/user_positions?user=0x22633134dc34f6c9a3bff51a0926c9d209714e26'
