# %%
import requests

# %%
address = "0x22633134dc34f6c9a3bff51a0926c9d209714e26"
URL = f"https://data-api.polymarket.com/positions?user={address}"

data = requests.get(URL).json()

# %%
for item in data:
    print(item["title"])
# Out:
# Will Polymarket US go live in 2025?
# Fed decreases interest rates by 50+ bps after October 2025 meeting?
# Bitcoin Up or Down on November 10?
# Will MrBeast hit 460 Million subscribers by December 31?
# Will "Demon Slayer" Opening Weekend Box Office be between $80m and $85m?
# Will Max Verstappen win the 2025 F1 Brazilian Grand Prix?
# Will "Demon Slayer" Opening Weekend Box Office be more than $85m?
# Will Wicked: For Good be the top grossing movie of 2025?
# Will Gemini 3.0 be released by November 15?

# %%
import pandas as pd
    
df = pd.DataFrame(data)
df["icon"].loc[0]
# Out:
# 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-polymarket-us-go-live-in-2025-dPC-pdwRSMZg.jpg'
